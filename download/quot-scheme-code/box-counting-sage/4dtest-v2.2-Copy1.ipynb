# %%
reset()
# %display latex
Partitions.options.latex="list"
load("partition_4d.sage")

# %%
load("vertex_4d.sage")
EasyEx=Partition4d([(0,0,0,0)])

# %% [markdown]
# Better code for vector bundle of rank 1 with weights $w_1,w_2,w_3$:

# %%
pretty(pretty(Vertex4d.Chern_Num(1))+pretty(Vertex4d.Verlinde_Num_inv(1)))
# Out:
# 0

# %%
pretty(Vertex4d.Verlinde_Num_inv(1))
# Out:
# -(t1*w1 + t2*w2 + t3*w3 + t1*w4 + t2*w5 + t3*w6)*(t1 + t2)*(t1 + t3)*(t2 + t3)/((t1 + t2 + t3)*t1*t2*t3)

# %%
pretty(Vertex4d.Chern_Num(2))
# Out:
# 1/2*(t1^3*t2*w1 + t1^2*t2^2*w1 + t1^3*t3*w1 + 2*t1^2*t2*t3*w1 + t1*t2^2*t3*w1 + t1^2*t3^2*w1 + t1*t2*t3^2*w1 + t1^2*t2^2*w2 + t1*t2^3*w2 + t1^2*t2*t3*w2 + 2*t1*t2^2*t3*w2 + t2^3*t3*w2 + t1*t2*t3^2*w2 + t2^2*t3^2*w2 + t1^2*t2*t3*w3 + t1*t2^2*t3*w3 + t1^2*t3^2*w3 + 2*t1*t2*t3^2*w3 + t2^2*t3^2*w3 + t1*t3^3*w3 + t2*t3^3*w3 - 5*t1^2*t2*t3 - 5*t1*t2^2*t3 - 5*t1*t2*t3^2 + t1^2*t2 + t1*t2^2 + t1^2*t3 + 2*t1*t2*t3 + t2^2*t3 + t1*t3^2 + t2*t3^2)*(t1*w1 + t2*w2 + t3*w3 + 1)*(t1 + t2)*(t1 + t3)*(t2 + t3)/((t1 + t2 + t3)^2*t1^2*t2^2*t3^2)

# %%
pretty(pretty(Vertex4d.Chern_Num(2))-pretty(Vertex4d.Verlinde_Num_inv(2)))
# Out:
# -1/2*(t1^2*w1^2 + 2*t1*t2*w1*w2 + t2^2*w2^2 + 2*t1*t3*w1*w3 + 2*t2*t3*w2*w3 + t3^2*w3^2 + t1^2*w4^2 + 2*t1*t2*w4*w5 + t2^2*w5^2 + 2*t1*t3*w4*w6 + 2*t2*t3*w5*w6 + t3^2*w6^2)*(t1 + t2)^2*(t1 + t3)^2*(t2 + t3)^2/((t1 + t2 + t3)^2*t1^2*t2^2*t3^2)

# %%
A=pretty(Vertex4d.Chern_Num(3))
B=pretty(Vertex4d.Verlinde_Num_inv(3))

# %%
pretty(A+B).__str__()
# Out:
# '-1/24*(14*t1^5*t2*w1^3 + 14*t1^4*t2^2*w1^3 + 14*t1^5*t3*w1^3 + 28*t1^4*t2*t3*w1^3 + 14*t1^3*t2^2*t3*w1^3 + 14*t1^4*t3^2*w1^3 + 14*t1^3*t2*t3^2*w1^3 + 42*t1^4*t2^2*w1^2*w2 + 42*t1^3*t2^3*w1^2*w2 + 42*t1^4*t2*t3*w1^2*w2 + 84*t1^3*t2^2*t3*w1^2*w2 + 42*t1^2*t2^3*t3*w1^2*w2 + 42*t1^3*t2*t3^2*w1^2*w2 + 42*t1^2*t2^2*t3^2*w1^2*w2 + 42*t1^3*t2^3*w1*w2^2 + 42*t1^2*t2^4*w1*w2^2 + 42*t1^3*t2^2*t3*w1*w2^2 + 84*t1^2*t2^3*t3*w1*w2^2 + 42*t1*t2^4*t3*w1*w2^2 + 42*t1^2*t2^2*t3^2*w1*w2^2 + 42*t1*t2^3*t3^2*w1*w2^2 + 14*t1^2*t2^4*w2^3 + 14*t1*t2^5*w2^3 + 14*t1^2*t2^3*t3*w2^3 + 28*t1*t2^4*t3*w2^3 + 14*t2^5*t3*w2^3 + 14*t1*t2^3*t3^2*w2^3 + 14*t2^4*t3^2*w2^3 + 42*t1^4*t2*t3*w1^2*w3 + 42*t1^3*t2^2*t3*w1^2*w3 + 42*t1^4*t3^2*w1^2*w3 + 84*t1^3*t2*t3^2*w1^2*w3 + 42*t1^2*t2^2*t3^2*w1^2*w3 + 42*t1^3*t3^3*w1^2*w3 + 42*t1^2*t2*t3^3*w1^2*w3 + 84*t1^3*t2^2*t3*w1*w2*w3 + 84*t1^2*t2^3*t3*w1*w2*w3 + 84*t1^3*t2*t3^2*w1*w2*w3 + 168*t1^2*t2^2*t3^2*w1*w2*w3 + 84*t1*t2^3*t3^2*w1*w2*w3 + 84*t1^2*t2*t3^3*w1*w2*w3 + 84*t1*t2^2*
# ...

# %% [markdown]
# difference multiple of $c_3^2$ checked for $n=-1,-2,-3,1,2,3$, rank $1$. Only holds for cannonical orientation!!
#
# $n=1,2,$ rank $2$

# %% [markdown]
# # degree -1

# %%
pretty(Vertex4d.Segre_Num(1,deg=-1))
# Out:
# (t1 + t2)*(t1 + t3)*(t2 + t3)/(b*(t1 + t2 + t3)*t1*t2*t3)

# %%
pretty(Vertex4d.Verlinde_Num(1,deg=-1))
# Out:
# (t1 + t2)*(t1 + t3)*(t2 + t3)/((t1 + t2 + t3)*t1*t2*t3)

# %%
pretty(Vertex4d.Segre_Num(2,deg=-1))
# Out:
# -1/2*(2*t1^3*t2*w1 + 2*t1^2*t2^2*w1 + 2*t1^3*t3*w1 + 4*t1^2*t2*t3*w1 + 2*t1*t2^2*t3*w1 + 2*t1^2*t3^2*w1 + 2*t1*t2*t3^2*w1 + 2*t1^2*t2^2*w2 + 2*t1*t2^3*w2 + 2*t1^2*t2*t3*w2 + 4*t1*t2^2*t3*w2 + 2*t2^3*t3*w2 + 2*t1*t2*t3^2*w2 + 2*t2^2*t3^2*w2 + 2*t1^2*t2*t3*w3 + 2*t1*t2^2*t3*w3 + 2*t1^2*t3^2*w3 + 4*t1*t2*t3^2*w3 + 2*t2^2*t3^2*w3 + 2*t1*t3^3*w3 + 2*t2*t3^3*w3 - 5*t1^2*t2*t3 - 5*t1*t2^2*t3 - 5*t1*t2*t3^2)*(t1 + t2)*(t1 + t3)*(t2 + t3)/(b*(t1 + t2 + t3)^2*t1^2*t2^2*t3^2)

# %%
pretty(Vertex4d.Verlinde_Num(2,deg=-1))
# Out:
# 1/4*(4*t1^3*t2*w1 + 4*t1^2*t2^2*w1 + 4*t1^3*t3*w1 + 8*t1^2*t2*t3*w1 + 4*t1*t2^2*t3*w1 + 4*t1^2*t3^2*w1 + 4*t1*t2*t3^2*w1 + 4*t1^2*t2^2*w2 + 4*t1*t2^3*w2 + 4*t1^2*t2*t3*w2 + 8*t1*t2^2*t3*w2 + 4*t2^3*t3*w2 + 4*t1*t2*t3^2*w2 + 4*t2^2*t3^2*w2 + 4*t1^2*t2*t3*w3 + 4*t1*t2^2*t3*w3 + 4*t1^2*t3^2*w3 + 8*t1*t2*t3^2*w3 + 4*t2^2*t3^2*w3 + 4*t1*t3^3*w3 + 4*t2*t3^3*w3 - 15*t1^2*t2*t3 - 15*t1*t2^2*t3 - 15*t1*t2*t3^2)*(t1 + t2)*(t1 + t3)*(t2 + t3)/((t1 + t2 + t3)^2*t1^2*t2^2*t3^2)

# %%
pretty((Vertex4d.Segre_Num(2,deg=-1))(b=1)+(Vertex4d.Verlinde_Num(2,deg=-1)))
# Out:
# -5/4*(t1 + t2)*(t1 + t3)*(t2 + t3)/((t1 + t2 + t3)*t1*t2*t3)

# %%
pretty(Vertex4d.Segre_Num(3,deg=-1))
# Out:
# 1/3*(3*t1^6*t2^2*w1^2 + 6*t1^5*t2^3*w1^2 + 3*t1^4*t2^4*w1^2 + 6*t1^6*t2*t3*w1^2 + 18*t1^5*t2^2*t3*w1^2 + 18*t1^4*t2^3*t3*w1^2 + 6*t1^3*t2^4*t3*w1^2 + 3*t1^6*t3^2*w1^2 + 18*t1^5*t2*t3^2*w1^2 + 30*t1^4*t2^2*t3^2*w1^2 + 18*t1^3*t2^3*t3^2*w1^2 + 3*t1^2*t2^4*t3^2*w1^2 + 6*t1^5*t3^3*w1^2 + 18*t1^4*t2*t3^3*w1^2 + 18*t1^3*t2^2*t3^3*w1^2 + 6*t1^2*t2^3*t3^3*w1^2 + 3*t1^4*t3^4*w1^2 + 6*t1^3*t2*t3^4*w1^2 + 3*t1^2*t2^2*t3^4*w1^2 + 6*t1^5*t2^3*w1*w2 + 12*t1^4*t2^4*w1*w2 + 6*t1^3*t2^5*w1*w2 + 12*t1^5*t2^2*t3*w1*w2 + 36*t1^4*t2^3*t3*w1*w2 + 36*t1^3*t2^4*t3*w1*w2 + 12*t1^2*t2^5*t3*w1*w2 + 6*t1^5*t2*t3^2*w1*w2 + 36*t1^4*t2^2*t3^2*w1*w2 + 60*t1^3*t2^3*t3^2*w1*w2 + 36*t1^2*t2^4*t3^2*w1*w2 + 6*t1*t2^5*t3^2*w1*w2 + 12*t1^4*t2*t3^3*w1*w2 + 36*t1^3*t2^2*t3^3*w1*w2 + 36*t1^2*t2^3*t3^3*w1*w2 + 12*t1*t2^4*t3^3*w1*w2 + 6*t1^3*t2*t3^4*w1*w2 + 12*t1^2*t2^2*t3^4*w1*w2 + 6*t1*t2^3*t3^4*w1*w2 + 3*t1^4*t2^4*w2^2 + 6*t1^3*t2^5*w2^2 + 3*t1^2*t2^6*w2^2 + 6*t1^4*t2^3*t3*w2^2 + 18*t1^3*t2^4*t3*w2^2 + 18*t1^2*t2^5*t3*w2^2 
# ...

# %%
pretty(Vertex4d.Verlinde_Num(3,deg=-1))
# Out:
# 1/36*(27*t1^6*t2^2*w1^2 + 54*t1^5*t2^3*w1^2 + 27*t1^4*t2^4*w1^2 + 54*t1^6*t2*t3*w1^2 + 162*t1^5*t2^2*t3*w1^2 + 162*t1^4*t2^3*t3*w1^2 + 54*t1^3*t2^4*t3*w1^2 + 27*t1^6*t3^2*w1^2 + 162*t1^5*t2*t3^2*w1^2 + 270*t1^4*t2^2*t3^2*w1^2 + 162*t1^3*t2^3*t3^2*w1^2 + 27*t1^2*t2^4*t3^2*w1^2 + 54*t1^5*t3^3*w1^2 + 162*t1^4*t2*t3^3*w1^2 + 162*t1^3*t2^2*t3^3*w1^2 + 54*t1^2*t2^3*t3^3*w1^2 + 27*t1^4*t3^4*w1^2 + 54*t1^3*t2*t3^4*w1^2 + 27*t1^2*t2^2*t3^4*w1^2 + 54*t1^5*t2^3*w1*w2 + 108*t1^4*t2^4*w1*w2 + 54*t1^3*t2^5*w1*w2 + 108*t1^5*t2^2*t3*w1*w2 + 324*t1^4*t2^3*t3*w1*w2 + 324*t1^3*t2^4*t3*w1*w2 + 108*t1^2*t2^5*t3*w1*w2 + 54*t1^5*t2*t3^2*w1*w2 + 324*t1^4*t2^2*t3^2*w1*w2 + 540*t1^3*t2^3*t3^2*w1*w2 + 324*t1^2*t2^4*t3^2*w1*w2 + 54*t1*t2^5*t3^2*w1*w2 + 108*t1^4*t2*t3^3*w1*w2 + 324*t1^3*t2^2*t3^3*w1*w2 + 324*t1^2*t2^3*t3^3*w1*w2 + 108*t1*t2^4*t3^3*w1*w2 + 54*t1^3*t2*t3^4*w1*w2 + 108*t1^2*t2^2*t3^4*w1*w2 + 54*t1*t2^3*t3^4*w1*w2 + 27*t1^4*t2^4*w2^2 + 54*t1^3*t2^5*w2^2 + 27*t1^2*t2^6*w2^2 + 54*t1^4*t2^3*t3*w2^2 + 1
# ...

# %%
pretty((Vertex4d.Segre_Num(3,deg=-1))(b=1)-(Vertex4d.Verlinde_Num(3,deg=-1)))
# Out:
# 1/36*(9*t1^6*t2^2*w1^2 + 18*t1^5*t2^3*w1^2 + 9*t1^4*t2^4*w1^2 + 18*t1^6*t2*t3*w1^2 + 54*t1^5*t2^2*t3*w1^2 + 54*t1^4*t2^3*t3*w1^2 + 18*t1^3*t2^4*t3*w1^2 + 9*t1^6*t3^2*w1^2 + 54*t1^5*t2*t3^2*w1^2 + 90*t1^4*t2^2*t3^2*w1^2 + 54*t1^3*t2^3*t3^2*w1^2 + 9*t1^2*t2^4*t3^2*w1^2 + 18*t1^5*t3^3*w1^2 + 54*t1^4*t2*t3^3*w1^2 + 54*t1^3*t2^2*t3^3*w1^2 + 18*t1^2*t2^3*t3^3*w1^2 + 9*t1^4*t3^4*w1^2 + 18*t1^3*t2*t3^4*w1^2 + 9*t1^2*t2^2*t3^4*w1^2 + 18*t1^5*t2^3*w1*w2 + 36*t1^4*t2^4*w1*w2 + 18*t1^3*t2^5*w1*w2 + 36*t1^5*t2^2*t3*w1*w2 + 108*t1^4*t2^3*t3*w1*w2 + 108*t1^3*t2^4*t3*w1*w2 + 36*t1^2*t2^5*t3*w1*w2 + 18*t1^5*t2*t3^2*w1*w2 + 108*t1^4*t2^2*t3^2*w1*w2 + 180*t1^3*t2^3*t3^2*w1*w2 + 108*t1^2*t2^4*t3^2*w1*w2 + 18*t1*t2^5*t3^2*w1*w2 + 36*t1^4*t2*t3^3*w1*w2 + 108*t1^3*t2^2*t3^3*w1*w2 + 108*t1^2*t2^3*t3^3*w1*w2 + 36*t1*t2^4*t3^3*w1*w2 + 18*t1^3*t2*t3^4*w1*w2 + 36*t1^2*t2^2*t3^4*w1*w2 + 18*t1*t2^3*t3^4*w1*w2 + 9*t1^4*t2^4*w2^2 + 18*t1^3*t2^5*w2^2 + 9*t1^2*t2^6*w2^2 + 18*t1^4*t2^3*t3*w2^2 + 54*t1^3*t2^4*t3*w2^2 +
# ...
